# %%
import pandas as pd

title_aka_df = pd.read_csv('zippedData/imdb.title.akas.csv.gz')
title_basics_df = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
title_crews_df = pd.read_csv('zippedData/imdb.title.crew.csv.gz')
title_principals_df = pd.read_csv('zippedData/imdb.title.principals.csv.gz')
title_ratings_df = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')

title_aka_df.shape
# Out:
# (331703, 8)

# %%
title_basics_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
merge1_df = title_basics_df.merge(title_aka_df, left_on='tconst', right_on='title_id')
merge1_df.head()
# Out:
#       tconst primary_title original_title  start_year  runtime_minutes  \
# 0  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 1  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 2  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 3  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 4  tt0063540     Sunghursh      Sunghursh        2013            175.0
#
#                genres   title_id  ordering      title region language  \
# 0  Action,Crime,Drama  tt0063540         1  Sangharsh     IN       hi
# 1  Action,Crime,Drama  tt0063540         2  Sunghursh    NaN      NaN
# 2  Action,Crime,Drama  tt0063540         3  Sunghursh     IN      NaN
# 3  Action,Crime,Drama  tt0063540         4  Sunghursh     IN       hi
# 4  Action,Crime,Drama  tt0063540         5  Sungharsh     IN       hi
#
#       types                   attributes  is_original_title
# ...

# %%
merge2_df = merge1_df.merge(title_crews_df, left_on='tconst', right_on='tconst')
merge2_df.head()
# Out:
#       tconst primary_title original_title  start_year  runtime_minutes  \
# 0  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 1  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 2  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 3  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 4  tt0063540     Sunghursh      Sunghursh        2013            175.0
#
#                genres   title_id  ordering      title region language  \
# 0  Action,Crime,Drama  tt0063540         1  Sangharsh     IN       hi
# 1  Action,Crime,Drama  tt0063540         2  Sunghursh    NaN      NaN
# 2  Action,Crime,Drama  tt0063540         3  Sunghursh     IN      NaN
# 3  Action,Crime,Drama  tt0063540         4  Sunghursh     IN       hi
# 4  Action,Crime,Drama  tt0063540         5  Sungharsh     IN       hi
#
#       types                   attributes  is_original_title  directors  \
# ...

# %%
merge3_df = merge2_df.merge(title_principals_df, left_on='tconst', right_on='tconst')
merge3_df.head()
# Out:
#       tconst primary_title original_title  start_year  runtime_minutes  \
# 0  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 1  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 2  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 3  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 4  tt0063540     Sunghursh      Sunghursh        2013            175.0
#
#                genres   title_id  ordering_x      title region  ... types  \
# 0  Action,Crime,Drama  tt0063540           1  Sangharsh     IN  ...   NaN
# 1  Action,Crime,Drama  tt0063540           1  Sangharsh     IN  ...   NaN
# 2  Action,Crime,Drama  tt0063540           1  Sangharsh     IN  ...   NaN
# 3  Action,Crime,Drama  tt0063540           1  Sangharsh     IN  ...   NaN
# 4  Action,Crime,Drama  tt0063540           1  Sangharsh     IN  ...   NaN
#
#                     attributes is_original_title  directors  \
# ...

# %%
final_merge_df = merge3_df.merge(title_ratings_df, left_on='tconst', right_on='tconst')
final_merge_df.head()
final_merge_df.shape
# Out:
# (2423186, 23)

# %% [markdown]
# Notes:
# -Not much here yet
